# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE
from sklearn.impute import SimpleImputer
from sklearn.model_selection import KFold

# %%
train_df = pd.read_csv("dataset/train_processed_last_version.csv")
test_df = pd.read_csv("dataset/test_processed_last_version.csv")

# %%
X_train = train_df.drop("label", axis=1)
y_train = train_df["label"]
X_test  = test_df.drop("label", axis=1)
y_test  = test_df["label"]

# %%
import tensorflow as tf
from tensorflow.keras import layers, models



def residual_block(x, units, dropout_rate=0.3):
    shortcut = x

    x = layers.Dense(units, activation='relu')(x)
    x = layers.Dropout(dropout_rate)(x)
    x = layers.Dense(units)(x)

    # Shortcut boyut eşleme
    if shortcut.shape[-1] != units:
        shortcut = layers.Dense(units)(shortcut)

    x = layers.Add()([x, shortcut])
    x = layers.Activation('relu')(x)

    return x


def create_residual_mlp(input_dim, num_classes=4):
    inputs = layers.Input(shape=(input_dim,))

    x = layers.Dense(128, activation='relu')(inputs)
    x = layers.Dropout(0.4)(x)

    x = residual_block(x, 128, dropout_rate=0.3)
    x = residual_block(x, 64, dropout_rate=0.3)

    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = models.Model(inputs, outputs)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )

    return model



best_accuracy = 0.0
kfold = KFold(n_splits=5, shuffle=True, random_state=42)
fold_no = 1
cv_scores = []

for train_index, val_index in kfold.split(X_train):

    print(f"\n------ Fold {fold_no} ------")

    # Split
    X_tr_raw, X_val_raw = X_train.iloc[train_index], X_train.iloc[val_index]
    y_tr, y_val = y_train.iloc[train_index], y_train.iloc[val_index]

    # Imputer
    imputer = SimpleImputer(strategy="median")
    X_tr = imputer.fit_transform(X_tr_raw)
    X_val = imputer.transform(X_val_raw)

    # SMOTE
    smote = SMOTE(random_state=42)
    X_tr_res, y_tr_res = smote.fit_resample(X_tr, y_tr)

    # Model
    model = create_residual_mlp(X_train.shape[1])

    # Train
    history = model.fit(
        X_tr_res, y_tr_res,
        validation_data=(X_val, y_val),
        epochs=50,
        batch_size=512,
        callbacks=[
            tf.keras.callbacks.EarlyStopping(
                monitor='val_loss',
                patience=10,
                restore_best_weights=True
            )
        ],
        verbose=1
    )

    scores = model.evaluate(X_val, y_val, verbose=0)
    cv_scores.append(scores[1])

    if scores[1] > best_accuracy:
        best_accuracy = scores[1]
        best_model = model
        model.save("best_model_Residual_MLP.h5")
        print(f"--> En iyi model fold {fold_no} olarak kaydedildi!")

    print(f"Fold {fold_no} Accuracy: {scores[1]:.4f}")
    fold_no += 1


print("\nK-Fold Ortalama Accuracy:", np.mean(cv_scores))
print("En iyi fold accuracy:", best_accuracy)
# Out:
# ------ Fold 1 ------
# Epoch 1/50
# 2052/2052 [==============================] - 13s 5ms/step - loss: 1.2503 - accuracy: 0.5777 - val_loss: 0.5620 - val_accuracy: 0.7725
# Epoch 2/50
# 2052/2052 [==============================] - 10s 5ms/step - loss: 0.4622 - accuracy: 0.8282 - val_loss: 0.2134 - val_accuracy: 0.9283
# Epoch 3/50
# 2052/2052 [==============================] - 9s 5ms/step - loss: 0.3049 - accuracy: 0.8930 - val_loss: 0.1776 - val_accuracy: 0.9409
# Epoch 4/50
# 2052/2052 [==============================] - 9s 4ms/step - loss: 0.2626 - accuracy: 0.9083 - val_loss: 0.1779 - val_accuracy: 0.9415
# Epoch 5/50
# 2052/2052 [==============================] - 9s 4ms/step - loss: 0.2406 - accuracy: 0.9159 - val_loss: 0.1664 - val_accuracy: 0.9434
# Epoch 6/50
# 2052/2052 [==============================] - 9s 5ms/step - loss: 0.2263 - accuracy: 0.9206 - val_loss: 0.1618 - val_accuracy: 0.9454
# Epoch 7/50
# 2052/2052 [==============================] - 9s 5ms/step - loss: 0.2161 - accuracy: 0.9240 - val_loss: 0.1494 - val_accuracy: 0.9479
# Epoch 8/50
# 2052/2052 [==============================] - 10s 5ms/step - loss: 0.2082 - accuracy: 0.9265 - val_loss: 0.1365 - val_accuracy: 0.9513
# Epoch 9/50
# 2052/2052 [==============================] - 10s 5ms/step - loss: 0.2024 - accuracy: 0.9284 - val_loss: 0.1444 - val_accuracy: 0.9504
# Epoch 10/50
# 2052/2052 [==============================] - 9s 5ms/step - loss: 0.1972 - accuracy: 0.9301 - val_loss: 0.1365 - val_accuracy: 0.9501
# Epoch 11/50
# 2052/2052 [==============================] - 10s 5ms/step - loss: 0.1918 - accuracy: 0.9318 - val_loss: 0.1342 - val_accuracy: 0.9515
# Epoch 12/50
# 2052/2052 [==============================] - 11s 5ms/step - loss: 0.1883 - accuracy: 0.9328 - val_loss: 0.1181 - val_accuracy: 0.9544
# Epoch 13/50
# 2052/2052 [==============================] - 10s 5ms/step - loss: 0.1843 - accuracy: 0.9340 - val_loss: 0.1224 - val_accuracy: 0.9551
# Epoch 14/50
# 2052/2052 [==============================] - 10s 5ms/step - loss: 0.1807 - accuracy: 0.9351 - val_loss: 0.1250 - val_accuracy: 0.9535
# Epoch 15/50
# 2052/2052 [==============================] - 10s 5ms/step - loss: 0.1791 - accuracy: 0.9356 - val_loss: 0.1276 - val_accuracy: 0.9549
# Epoch 16/50
# 2052/2052 [==============================] - 10s 5ms/step - loss: 0.1762 - accuracy: 0.9367 - val_loss: 0.1124 - val_accuracy: 0.9572
# Epoch 17/50
# 2052/2052 [==============================] - 10s 5ms/step - loss: 0.1740 - accuracy: 0.9373 - val_loss: 0.1203 - val_accuracy: 0.9560
# Epoch 18/50
# 2052/2052 [==============================] - 10s 5ms/step - loss: 0.1717 - accuracy: 0.9381 - val_loss: 0.1238 - val_accuracy: 0.9547
# Epoch 19/50
# 2052/2052 [==============================] - 10s 5ms/step - loss: 0.1707 - accuracy: 0.9384 - val_loss: 0.1161 - val_accuracy: 0.9560
# Epoch 20/50
# 2052/2052 [==============================] - 10s 5ms/step - loss: 0.1689 - accuracy: 0.9391 - val_loss: 0.1138 - val_accuracy: 0.9587
# Epoch 21/50
# 2052/2052 [==============================] - 9s 5ms/step - loss: 0.1675 - accuracy: 0.9394 - val_loss: 0.1160 - val_accuracy: 0.9561
# Epoch 22/50
# 2052/2052 [==============================] - 9s 5ms/step - loss: 0.1651 - accuracy: 0.9401 - val_loss: 0.1251 - val_accuracy: 0.9555
# Epoch 23/50
# 2052/2052 [==============================] - 9s 5ms/step - loss: 0.1644 - accuracy: 0.9406 - val_loss: 0.1240 - val_accuracy: 0.9550
# Epoch 24/50
# 2052/2052 [==============================] - 9s 5ms/step - loss: 0.1630 - accuracy: 0.9412 - val_loss: 0.1128 - val_accuracy: 0.9567
# Epoch 25/50
# 2052/2052 [==============================] - 9s 5ms/step - loss: 0.1624 - accuracy: 0.9412 - val_loss: 0.1088 - val_accuracy: 0.9589
# Epoch 26/50
# 2052/2052 [==============================] - 9s 5ms/step - loss: 0.1607 - accuracy: 0.9418 - val_loss: 0.1108 - val_accuracy: 0.9585
# Epoch 27/50
# 2052/2052 [==============================] - 9s 5ms/step - loss: 0.1597 - accuracy: 0.9422 - val_loss: 0.1116 - val_accuracy: 0.9584
# Epoch 28/50
# 2052/2052 [==============================] - 9s 5ms/step - loss: 0.1579 - accuracy: 0.9427 - val_loss: 0.1137 - val_accuracy: 0.9572
# Epoch 29/50
# 2052/2052 [==============================] - 9s 5ms/step - loss: 0.1577 - accuracy: 0.9431 - val_loss: 0.1235 - val_accuracy: 0.9550
# Epoch 30/50
# 2052/2052 [==============================] - 9s 5ms/step - loss: 0.1558 - accuracy: 0.9433 - val_loss: 0.1240 - val_accuracy: 0.9553
# Epoch 31/50
# 2052/2052 [==============================] - 9s 5ms/step - loss: 0.1551 - accuracy: 0.9438 - val_loss: 0.1115 - val_accuracy: 0.9585
# Epoch 32/50
# 2052/2052 [==============================] - 9s 5ms/step - loss: 0.1544 - accuracy: 0.9439 - val_loss: 0.1237 - val_accuracy: 0.9540
# Epoch 33/50
# 2052/2052 [==============================] - 11s 5ms/step - loss: 0.1536 - accuracy: 0.9442 - val_loss: 0.1149 - val_accuracy: 0.9583
# Epoch 34/50
# 2052/2052 [==============================] - 10s 5ms/step - loss: 0.1534 - accuracy: 0.9443 - val_loss: 0.1194 - val_accuracy: 0.9541
# Epoch 35/50
# 2052/2052 [==============================] - 10s 5ms/step - loss: 0.1521 - accuracy: 0.9445 - val_loss: 0.1118 - val_accuracy: 0.9579
# --> En iyi model fold 1 olarak kaydedildi!
# Fold 1 Accuracy: 0.9589
#
# ------ Fold 2 ------
# Epoch 1/50
# 2056/2056 [==============================] - 10s 5ms/step - loss: 1.2826 - accuracy: 0.6069 - val_loss: 0.5103 - val_accuracy: 0.7954
# Epoch 2/50
# 2056/2056 [==============================] - 10s 5ms/step - loss: 0.4422 - accuracy: 0.8397 - val_loss: 0.2291 - val_accuracy: 0.9194
# Epoch 3/50
# 2056/2056 [==============================] - 10s 5ms/step - loss: 0.3107 - accuracy: 0.8900 - val_loss: 0.1907 - val_accuracy: 0.9332
# Epoch 4/50
# 2056/2056 [==============================] - 10s 5ms/step - loss: 0.2701 - accuracy: 0.9051 - val_loss: 0.1678 - val_accuracy: 0.9413
# Epoch 5/50
# 2056/2056 [==============================] - 10s 5ms/step - loss: 0.2463 - accuracy: 0.9136 - val_loss: 0.1697 - val_accuracy: 0.9442
# Epoch 6/50
# 2056/2056 [==============================] - 9s 5ms/step - loss: 0.2311 - accuracy: 0.9194 - val_loss: 0.1725 - val_accuracy: 0.9410
# Epoch 7/50
# 2056/2056 [==============================] - 10s 5ms/step - loss: 0.2217 - accuracy: 0.9222 - val_loss: 0.1597 - val_accuracy: 0.9435
# Epoch 8/50
# 2056/2056 [==============================] - 10s 5ms/step - loss: 0.2122 - accuracy: 0.9255 - val_loss: 0.1477 - val_accuracy: 0.9471
# Epoch 9/50
# 2056/2056 [==============================] - 10s 5ms/step - loss: 0.2053 - accuracy: 0.9280 - val_loss: 0.1416 - val_accuracy: 0.9492
# Epoch 10/50
# 2056/2056 [==============================] - 11s 5ms/step - loss: 0.1985 - accuracy: 0.9299 - val_loss: 0.1546 - val_accuracy: 0.9443
# Epoch 11/50
# 2056/2056 [==============================] - 11s 5ms/step - loss: 0.1938 - accuracy: 0.9314 - val_loss: 0.1418 - val_accuracy: 0.9490
# Epoch 12/50
# 2056/2056 [==============================] - 10s 5ms/step - loss: 0.1895 - accuracy: 0.9328 - val_loss: 0.1420 - val_accuracy: 0.9493
# Epoch 13/50
# 2056/2056 [==============================] - 10s 5ms/step - loss: 0.1854 - accuracy: 0.9340 - val_loss: 0.1324 - val_accuracy: 0.9529
# Epoch 14/50
# 2056/2056 [==============================] - 10s 5ms/step - loss: 0.1812 - accuracy: 0.9353 - val_loss: 0.1327 - val_accuracy: 0.9513
# Epoch 15/50
# 2056/2056 [==============================] - 10s 5ms/step - loss: 0.1782 - accuracy: 0.9364 - val_loss: 0.1371 - val_accuracy: 0.9494
# Epoch 16/50
# 2056/2056 [==============================] - 10s 5ms/step - loss: 0.1760 - accuracy: 0.9371 - val_loss: 0.1392 - val_accuracy: 0.9465
# Epoch 17/50
# 2056/2056 [==============================] - 10s 5ms/step - loss: 0.1730 - accuracy: 0.9381 - val_loss: 0.1305 - val_accuracy: 0.9506
# Epoch 18/50
# 2056/2056 [==============================] - 10s 5ms/step - loss: 0.1715 - accuracy: 0.9383 - val_loss: 0.1227 - val_accuracy: 0.9539
# Epoch 19/50
# 2056/2056 [==============================] - 10s 5ms/step - loss: 0.1695 - accuracy: 0.9389 - val_loss: 0.1436 - val_accuracy: 0.9442
# Epoch 20/50
# 2056/2056 [==============================] - 10s 5ms/step - loss: 0.1676 - accuracy: 0.9398 - val_loss: 0.1201 - val_accuracy: 0.9526
# Epoch 21/50
# 2056/2056 [==============================] - 10s 5ms/step - loss: 0.1663 - accuracy: 0.9403 - val_loss: 0.1220 - val_accuracy: 0.9535
# Epoch 22/50
# 2056/2056 [==============================] - 10s 5ms/step - loss: 0.1648 - accuracy: 0.9407 - val_loss: 0.1236 - val_accuracy: 0.9523
# Epoch 23/50
# 2056/2056 [==============================] - 10s 5ms/step - loss: 0.1632 - accuracy: 0.9412 - val_loss: 0.1286 - val_accuracy: 0.9505
# Epoch 24/50
# 2056/2056 [==============================] - 10s 5ms/step - loss: 0.1615 - accuracy: 0.9417 - val_loss: 0.1241 - val_accuracy: 0.9532
# Epoch 25/50
# 2056/2056 [==============================] - 10s 5ms/step - loss: 0.1609 - accuracy: 0.9420 - val_loss: 0.1301 - val_accuracy: 0.9510
# Epoch 26/50
# 2056/2056 [==============================] - 10s 5ms/step - loss: 0.1598 - accuracy: 0.9423 - val_loss: 0.1223 - val_accuracy: 0.9517
# Epoch 27/50
# 2056/2056 [==============================] - 10s 5ms/step - loss: 0.
50
# 2053/2053 [==============================] - 10s 5ms/step - loss: 0.1635 - accuracy: 0.9415 - val_loss: 0.1281 - val_accuracy: 0.9524
# Epoch 28/50
# 2053/2053 [==============================] - 10s 5ms/step - loss: 0.1619 - accuracy: 0.9419 - val_loss: 0.1300 - val_accuracy: 0.9519
# Epoch 29/50
# 2053/2053 [==============================] - 10s 5ms/step - loss: 0.1612 - accuracy: 0.9421 - val_loss: 0.1236 - val_accuracy: 0.9537
# Epoch 30/50
# 2053/2053 [==============================] - 10s 5ms/step - loss: 0.1606 - accuracy: 0.9423 - val_loss: 0.1156 - val_accuracy: 0.9552
# Epoch 31/50
# 2053/2053 [==============================] - 11s 5ms/step - loss: 0.1585 - accuracy: 0.9431 - val_loss: 0.1186 - val_accuracy: 0.9538
# Epoch 32/50
# 2053/2053 [==============================] - 11s 5ms/step - loss: 0.1580 - accuracy: 0.9429 - val_loss: 0.1220 - val_accuracy: 0.9521
# Epoch 33/50
# 2053/2053 [==============================] - 10s 5ms/step - loss: 0.1571 - accuracy: 0.9432 - val_loss: 0.1282 - val_accuracy: 0.9516
# Epoch 34/50
# 2053/2053 [==============================] - 10s 5ms/step - loss: 0.1563 - accuracy: 0.9436 - val_loss: 0.1194 - val_accuracy: 0.9535
# Epoch 35/50
# 2053/2053 [==============================] - 10s 5ms/step - loss: 0.1548 - accuracy: 0.9441 - val_loss: 0.1222 - val_accuracy: 0.9528
# Epoch 36/50
# 2053/2053 [==============================] - 10s 5ms/step - loss: 0.1536 - accuracy: 0.9447 - val_loss: 0.1117 - val_accuracy: 0.9548
# Epoch 37/50
# 2053/2053 [==============================] - 10s 5ms/step - loss: 0.1535 - accuracy: 0.9444 - val_loss: 0.1231 - val_accuracy: 0.9521
# Epoch 38/50
# 2053/2053 [==============================] - 10s 5ms/step - loss: 0.1523 - accuracy: 0.9449 - val_loss: 0.1111 - val_accuracy: 0.9557
# Epoch 39/50
# 2053/2053 [==============================] - 10s 5ms/step - loss: 0.1508 - accuracy: 0.9454 - val_loss: 0.1271 - val_accuracy: 0.9528
# Epoch 40/50
# 2053/2053 [==============================] - 10s 5ms/step - loss: 0.1507 - accuracy: 0.9453 - val_loss: 0.1121 - val_accuracy: 0.9551
# Epoch 41/50
# 2053/2053 [==============================] - 10s 5ms/step - loss: 0.1504 - accuracy: 0.9456 - val_loss: 0.1282 - val_accuracy: 0.9538
# Epoch 42/50
# 2053/2053 [==============================] - 10s 5ms/step - loss: 0.1492 - accuracy: 0.9460 - val_loss: 0.1225 - val_accuracy: 0.9530
# Epoch 43/50
# 2053/2053 [==============================] - 10s 5ms/step - loss: 0.1490 - accuracy: 0.9459 - val_loss: 0.1172 - val_accuracy: 0.9553
# Epoch 44/50
# 2053/2053 [==============================] - 10s 5ms/step - loss: 0.1491 - accuracy: 0.9462 - val_loss: 0.1134 - val_accuracy: 0.9573
# Epoch 45/50
# 2053/2053 [==============================] - 10s 5ms/step - loss: 0.1475 - accuracy: 0.9466 - val_loss: 0.1126 - val_accuracy: 0.9582
# Epoch 46/50
# 2053/2053 [==============================] - 10s 5ms/step - loss: 0.1471 - accuracy: 0.9466 - val_loss: 0.1152 - val_accuracy: 0.9546
# Epoch 47/50
# 2053/2053 [==============================] - 10s 5ms/step - loss: 0.1471 - accuracy: 0.9466 - val_loss: 0.1232 - val_accuracy: 0.9533
# Epoch 48/50
# 2053/2053 [==============================] - 10s 5ms/step - loss: 0.1453 - accuracy: 0.9472 - val_loss: 0.1211 - val_accuracy: 0.9558
# Fold 3 Accuracy: 0.9556
#
# ------ Fold 4 ------
# Epoch 1/50
# 2056/2056 [==============================] - 11s 5ms/step - loss: 1.3119 - accuracy: 0.5150 - val_loss: 0.7299 - val_accuracy: 0.6432
# Epoch 2/50
# 2056/2056 [==============================] - 10s 5ms/step - loss: 0.5504 - accuracy: 0.7923 - val_loss: 0.2565 - val_accuracy: 0.9063
# Epoch 3/50
# 2056/2056 [==============================] - 10s 5ms/step - loss: 0.3359 - accuracy: 0.8805 - val_loss: 0.1987 - val_accuracy: 0.9304
# Epoch 4/50
# 2056/2056 [==============================] - 10s 5ms/step - loss: 0.2804 - accuracy: 0.9015 - val_loss: 0.1871 - val_accuracy: 0.9343
# Epoch 5/50
# 2056/2056 [==============================] - 10s 5ms/step - loss: 0.2528 - accuracy: 0.9119 - val_loss: 0.1772 - val_accuracy: 0.9393
# Epoch 6/50
# 2056/2056 [==============================] - 10s 5ms/step - loss: 0
50
# 2053/2053 [==============================] - 9s 5ms/step - loss: 0.1619 - accuracy: 0.9410 - val_loss: 0.1180 - val_accuracy: 0.9550
# Epoch 25/50
# 2053/2053 [==============================] - 9s 4ms/step - loss: 0.1599 - accuracy: 0.9418 - val_loss: 0.1115 - val_accuracy: 0.9554
# Epoch 26/50
# 2053/2053 [==============================] - 9s 5ms/step - loss: 0.1595 - accuracy: 0.9417 - val_loss: 0.1227 - val_accuracy: 0.9529
# Epoch 27/50
# 2053/2053 [==============================] - 9s 5ms/step - loss: 0.1581 - accuracy: 0.9423 - val_loss: 0.1212 - val_accuracy: 0.9539
# Epoch 28/50
# 2053/2053 [==============================] - 9s 5ms/step - loss: 0.1573 - accuracy: 0.9425 - val_loss: 0.1181 - val_accuracy: 0.9526
# Epoch 29/50
# 2053/2053 [==============================] - 9s 4ms/step - loss: 0.1554 - accuracy: 0.9431 - val_loss: 0.1145 - val_accuracy: 0.9558
# Epoch 30/50
# 2053/2053 [==============================] - 9s 4ms/step - loss: 0.1553 - accuracy: 0.9432 - val_loss: 0.1202 - val_accuracy: 0.9537
# Epoch 31/50
# 2053/2053 [==============================] - 9s 5ms/step - loss: 0.1534 - accuracy: 0.9438 - val_loss: 0.1203 - val_accuracy: 0.9526
# Epoch 32/50
# 2053/2053 [==============================] - 10s 5ms/step - loss: 0.1526 - accuracy: 0.9441 - val_loss: 0.1195 - val_accuracy: 0.9534
# Fold 5 Accuracy: 0.9581
#
# K-Fold Ortalama Accuracy: 0.9597725510597229
# En iyi fold accuracy: 0.9736989140510559

# %%
from sklearn.metrics import f1_score

final_imputer = imputer

X_test_imputed = final_imputer.transform(X_test)
y_pred_probs = model.predict(X_test_imputed)
y_pred = np.argmax(y_pred_probs, axis=1)

test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
test_f1 = f1_score(y_test, y_pred, average="weighted")

print("\nTest Accuracy:", test_acc)
print("Test F1 Score:", test_f1)
# Out:
# 3921/3921 [==============================] - 5s 1ms/step
#
# Test Accuracy: 0.9590739011764526
# Test F1 Score: 0.9600286995735026

# %%
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_auc_score

y_test_bin = label_binarize(y_test, classes=[0,1,2,3])

test_auc = roc_auc_score(
    y_test_bin,
    y_pred_probs,
    average="weighted",
    multi_class="ovr"
)

print("Test AUC:", test_auc)
# Out:
# Test AUC: 0.998303413431143

# %%
from sklearn.metrics import confusion_matrix, classification_report

class_names = ['Benign (0)', 'Defacement (1)', 'Phishing (2)', 'Malware (3)']

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Reds', 
            xticklabels=class_names, 
            yticklabels=class_names)
plt.title('Confusion Matrix (Model Tahmin Analizi)')
plt.ylabel('Gerçek Sınıf')
plt.xlabel('Tahmin Edilen Sınıf')
plt.show()


print("\n--- Sınıflandırma Raporu ---")
print(classification_report(y_test, y_pred, target_names=class_names))
# Out:
# --- Sınıflandırma Raporu ---
#                 precision    recall  f1-score   support
#
#     Benign (0)       1.00      0.96      0.98     84093
# Defacement (1)       0.95      0.97      0.96     19288
#   Phishing (2)       0.84      0.95      0.89     16329
#    Malware (3)       0.86      0.92      0.89      5760
#
#       accuracy                           0.96    125470
#      macro avg       0.91      0.95      0.93    125470
#   weighted avg       0.96      0.96      0.96    125470

# %%
plt.figure(figsize=(8, 5))
plt.plot(history.history["accuracy"], label="Train Accuracy")
plt.plot(history.history["val_accuracy"], label="Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Train and Validation Accuracy over Epochs")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Train and Validation Loss over Epochs")
plt.legend()
plt.grid(True)
plt.show()
