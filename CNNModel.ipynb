# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE
from sklearn.impute import SimpleImputer
from sklearn.model_selection import KFold

# %%
train_df = pd.read_csv("dataset/train_processed_last_version.csv")
test_df = pd.read_csv("dataset/test_processed_last_version.csv")

# %%
X_train = train_df.drop("label", axis=1)
y_train = train_df["label"]
X_test  = test_df.drop("label", axis=1)
y_test  = test_df["label"]

# %%
import tensorflow as tf
from tensorflow.keras import layers, models



def create_cnn_model(input_dim, num_classes=4):

    inputs = layers.Input(shape=(input_dim,))

    x = layers.Reshape((input_dim, 1))(inputs)

    x = layers.Conv1D(
        filters=64,
        kernel_size=3,
        activation="relu",
        padding="same"
    )(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling1D(pool_size=2)(x)

    x = layers.Conv1D(
        filters=128,
        kernel_size=3,
        activation="relu",
        padding="same"
    )(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling1D(pool_size=2)(x)

    x = layers.Flatten()(x)

    x = layers.Dense(128, activation="relu")(x)
    x = layers.Dropout(0.4)(x)

    outputs = layers.Dense(num_classes, activation="softmax")(x)

    model = models.Model(inputs, outputs)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )

    return model



best_accuracy = 0.0
kfold = KFold(n_splits=5, shuffle=True, random_state=42)
fold_no = 1
cv_scores = []

for train_index, val_index in kfold.split(X_train):

    print(f"\n------ Fold {fold_no} ------")

    X_tr_raw, X_val_raw = X_train.iloc[train_index], X_train.iloc[val_index]
    y_tr, y_val = y_train.iloc[train_index], y_train.iloc[val_index]

    # Imputer
    imputer = SimpleImputer(strategy="median")
    X_tr = imputer.fit_transform(X_tr_raw)
    X_val = imputer.transform(X_val_raw)

    # SMOTE
    smote = SMOTE(random_state=42)
    X_tr_res, y_tr_res = smote.fit_resample(X_tr, y_tr)

    # Model
    model = create_cnn_model(X_train.shape[1])

    # Train
    history = model.fit(
        X_tr_res, y_tr_res,
        validation_data=(X_val, y_val),
        epochs=50,
        batch_size=512,
        callbacks=[
            tf.keras.callbacks.EarlyStopping(
                monitor="val_loss",
                patience=10,
                restore_best_weights=True
            )
        ],
        verbose=1
    )

    scores = model.evaluate(X_val, y_val, verbose=0)
    cv_scores.append(scores[1])

    if scores[1] > best_accuracy:
        best_accuracy = scores[1]
        best_model = model
        model.save("best_model_CNN.h5")
        print(f"--> En iyi model fold {fold_no} olarak kaydedildi!")

    print(f"Fold {fold_no} Accuracy: {scores[1]:.4f}")
    fold_no += 1


print("\nK-Fold Ortalama Accuracy:", np.mean(cv_scores))
print("En iyi fold accuracy:", best_accuracy)
# Out:
# ------ Fold 1 ------
# Epoch 1/50
# 2052/2052 [==============================] - 26s 9ms/step - loss: 0.2603 - accuracy: 0.9072 - val_loss: 0.1602 - val_accuracy: 0.9502
# Epoch 2/50
# 2052/2052 [==============================] - 19s 9ms/step - loss: 0.1349 - accuracy: 0.9530 - val_loss: 0.0986 - val_accuracy: 0.9686
# Epoch 3/50
# 2052/2052 [==============================] - 19s 9ms/step - loss: 0.1131 - accuracy: 0.9605 - val_loss: 0.0604 - val_accuracy: 0.9808
# Epoch 4/50
# 2052/2052 [==============================] - 19s 9ms/step - loss: 0.1037 - accuracy: 0.9636 - val_loss: 0.0734 - val_accuracy: 0.9771
# Epoch 5/50
# 2052/2052 [==============================] - 19s 9ms/step - loss: 0.0964 - accuracy: 0.9661 - val_loss: 0.0527 - val_accuracy: 0.9841
# Epoch 6/50
# 2052/2052 [==============================] - 19s 9ms/step - loss: 0.0915 - accuracy: 0.9677 - val_loss: 0.1336 - val_accuracy: 0.9578
# Epoch 7/50
# 2052/2052 [==============================] - 19s 9ms/step - loss: 0.0890 - accuracy: 0.9683 - val_loss: 0.0769 - val_accuracy: 0.9787
# Epoch 8/50
# 2052/2052 [==============================] - 19s 9ms/step - loss: 0.0853 - accuracy: 0.9697 - val_loss: 0.0620 - val_accuracy: 0.9821
# Epoch 9/50
# 2052/2052 [==============================] - 20s 10ms/step - loss: 0.0827 - accuracy: 0.9706 - val_loss: 0.0738 - val_accuracy: 0.9772
# Epoch 10/50
# 2052/2052 [==============================] - 19s 9ms/step - loss: 0.0816 - accuracy: 0.9709 - val_loss: 0.0591 - val_accuracy: 0.9831
# Epoch 11/50
# 2052/2052 [==============================] - 19s 9ms/step - loss: 0.0794 - accuracy: 0.9717 - val_loss: 0.0453 - val_accuracy: 0.9868
# Epoch 12/50
# 2052/2052 [==============================] - 19s 9ms/step - loss: 0.0776 - accuracy: 0.9723 - val_loss: 0.0525 - val_accuracy: 0.9843
# Epoch 13/50
# 2052/2052 [==============================] - 20s 10ms/step - loss: 0.0755 - accuracy: 0.9729 - val_loss: 0.0492 - val_accuracy: 0.9861
# Epoch 14/50
# 2052/2052 [==============================] - 24s 12ms/step - loss: 0.0744 - accuracy: 0.9733 - val_loss: 0.0560 - val_accuracy: 0.9839
# Epoch 15/50
# 2052/2052 [==============================] - 22s 11ms/step - loss: 0.0725 - accuracy: 0.9739 - val_loss: 0.0452 - val_accuracy: 0.9878
# Epoch 16/50
# 2052/2052 [==============================] - 23s 11ms/step - loss: 0.0716 - accuracy: 0.9741 - val_loss: 0.0436 - val_accuracy: 0.9882
# Epoch 17/50
# 2052/2052 [==============================] - 21s 10ms/step - loss: 0.0717 - accuracy: 0.9742 - val_loss: 0.0529 - val_accuracy: 0.9850
# Epoch 18/50
# 2052/2052 [==============================] - 21s 10ms/step - loss: 0.0693 - accuracy: 0.9750 - val_loss: 0.0526 - val_accuracy: 0.9849
# Epoch 19/50
# 2052/2052 [==============================] - 21s 10ms/step - loss: 0.0686 - accuracy: 0.9752 - val_loss: 0.0418 - val_accuracy: 0.9891
# Epoch 20/50
# 2052/2052 [==============================] - 21s 10ms/step - loss: 0.0680 - accuracy: 0.9755 - val_loss: 0.0432 - val_accuracy: 0.9884
# Epoch 21/50
# 2052/2052 [==============================] - 21s 10ms/step - loss: 0.0676 - accuracy: 0.9755 - val_loss: 0.0513 - val_accuracy: 0.9855
# Epoch 22/50
# 2052/2052 [==============================] - 21s 10ms/step - loss: 0.0657 - accuracy: 0.9762 - val_loss: 0.0597 - val_accuracy: 0.9845
# Epoch 23/50
# 2052/2052 [==============================] - 21s 10ms/step - loss: 0.0652 - accuracy: 0.9763 - val_loss: 0.0423 - val_accuracy: 0.9891
# Epoch 24/50
# 2052/2052 [==============================] - 20s 10ms/step - loss: 0.0653 - accuracy: 0.9764 - val_loss: 0.0473 - val_accuracy: 0.9871
# Epoch 25/50
# 2052/2052 [==============================] - 20s 10ms/step - loss: 0.0641 - accuracy: 0.9767 - val_loss: 0.0444 - val_accuracy: 0.9888
# Epoch 26/50
# 2052/2052 [==============================] - 20s 10ms/step - loss: 0.0636 - accuracy: 0.9768 - val_loss: 0.0463 - val_accuracy: 0.9883
# Epoch 27/50
# 2052/2052 [==============================] - 20s 10ms/step - loss: 0.0628 - accuracy: 0.9771 - val_loss: 0.0435 - val_accuracy: 0.9888
# Epoch 28/50
# 2052/2052 [==============================] - 20s 10ms/step - loss: 0.0626 - accuracy: 0.9772 - val_loss: 0.0728 - val_accuracy: 0.9764
# Epoch 29/50
# 2052/2052 [==============================] - 20s 10ms/step - loss: 0.0618 - accuracy: 0.9776 - val_loss: 0.0444 - val_accuracy: 0.9888
# --> En iyi model fold 1 olarak kaydedildi!
# Fold 1 Accuracy: 0.9891
#
# ------ Fold 2 ------
# Epoch 1/50
# 2056/2056 [==============================] - 20s 9ms/step - loss: 0.2811 - accuracy: 0.8987 - val_loss: 0.1540 - val_accuracy: 0.9497
# Epoch 2/50
# 2056/2056 [==============================] - 22s 11ms/step - loss: 0.1611 - accuracy: 0.9426 - val_loss: 0.0819 - val_accuracy: 0.9731
# Epoch 3/50
# 2056/2056 [==============================] - 21s 10ms/step - loss: 0.1335 - accuracy: 0.9521 - val_loss: 0.0708 - val_accuracy: 0.9781
# Epoch 4/50
# 2056/2056 [==============================] - 20s 10ms/step - loss: 0.1199 - accuracy: 0.9568 - val_loss: 0.0989 - val_accuracy: 0.9696
# Epoch 5/50
# 2056/2056 [==============================] - 20s 10ms/step - loss: 0.1122 - accuracy: 0.9596 - val_loss: 0.0603 - val_accuracy: 0.9822
# Epoch 6/50
# 2056/2056 [==============================] - 20s 10ms/step - loss: 0.1046 - accuracy: 0.9626 - val_loss: 0.0596 - val_accuracy: 0.9819
# Epoch 7/50
# 2056/2056 [==============================] - 20s 10ms/step - loss: 0.0970 - accuracy: 0.9657 - val_loss: 0.0590 - val_accuracy: 0.9833
# Epoch 8/50
# 2056/2056 [==============================] - 20s 10ms/step - loss: 0.0915 - accuracy: 0.9676 - val_loss: 0.0614 - val_accuracy: 0.9815
# Epoch 9/50
# 2056/2056 [==============================] - 20s 10ms/step - loss: 0.0895 - accuracy: 0.9684 - val_loss: 0.0479 - val_accuracy: 0.9859
# Epoch 10/50
# 2056/2056 [==============================] - 22s 11ms/step - loss: 0.0859 - accuracy: 0.9697 - val_loss: 0.0620 - val_accuracy: 0.9823
# Epoch 11/50
# 2056/2056 [==============================] - 21s 10ms/step - loss: 0.0829 - accuracy: 0.9704 - val_loss: 0.0644 - val_accuracy: 0.9808
# Epoch 12/50
# 2056/2056 [==============================] - 21s 10ms/step - loss: 0.0811 - accuracy: 0.9711 - val_loss: 0.0537 - val_accuracy: 0.9831
# Epoch 13/50
# 2056/2056 [==============================] - 21s 10ms/step - loss: 0.0790 - accuracy: 0.9717 - val_loss: 0.0567 - val_accuracy: 0.9838
# Epoch 14/50
# 2056/2056 [==============================] - 21s 10ms/step - loss: 0.0778 - accuracy: 0.9722 - val_loss: 0.0489 - val_accuracy: 0.9864
# Epoch 15/50
# 2056/2056 [==============================] - 20s 10ms/step - loss: 0.0764 - accuracy: 0.9725 - val_loss: 0.0721 - val_accuracy: 0.9799
# Epoch 16/50
# 2056/2056 [==============================] - 20s 10ms/step - loss: 0.0750 - accuracy: 0.9732 - val_loss: 0.0427 - val_accuracy: 0.9881
# Epoch 17/50
# 2056/2056 [==============================] - 21s 10ms/step - loss: 0.0740 - accuracy: 0.9734 - val_loss: 0.0493 - val_accuracy: 0.9867
# Epoch 18/50
# 2056/2056 [==============================] - 21s 10ms/step - loss: 0.0726 - accuracy: 0.9739 - val_loss: 0.0431 - val_accuracy: 0.9878
# Epoch 19/50
# 2056/2056 [==============================] - 21s 10ms/step - loss: 0.0716 - accuracy: 0.9740 - val_loss: 0.0435 - val_accuracy: 0.9883
# Epoch 20/50
# 2056/2056 [==============================] - 21s 10ms/step - loss: 0.0710 - accuracy: 0.9743 - val_loss: 0.0414 - val_accuracy: 0.9882
# Epoch 21/50
# 2056/2056 [==============================] - 21s 10ms/step - loss: 0.0695 - accuracy: 0.9748 - val_loss: 0.0434 - val_accuracy: 0.9885
# Epoch 22/50
# 2056/2056 [==============================] - 21s 10ms/step - loss: 0.0693 - accuracy: 0.9748 - val_loss: 0.0431 - val_accuracy: 0.9876
# Epoch 23/50
# 2056/2056 [==============================] - 21s 10ms/step - loss: 0.0683 - accuracy: 0.9752 - val_loss: 0.0431 - val_accuracy: 0.9883
# Epoch 24/50
# 2056/2056 [==============================] - 22s 11ms/step - loss: 0.0675 - accuracy: 0.9753 - val_loss: 0.0464 - val_accuracy: 0.9865
# Epoch 25/50
# 2056/2056 [==============================] - 21s 10ms/step - loss: 0.0672 - accuracy: 0.9753 - val_loss: 0.0428 - val_accuracy: 0.9884
# Epoch 26/50
# 2056/2056 [==============================] - 24s 12ms/step - loss: 0.0662 - accuracy: 0.9757 - val_loss: 0.0461 - val_accuracy: 0.9873
# Epoch 27/50
# 2056/2056 [==============================] - 22s 11ms/step - loss: 0.0654 - accuracy: 0.9762 - val_loss: 0.0456 - val_accuracy: 0.9873
# Epoch 28/50
# 2056/2056 [==============================] - 21s 10ms/step - loss: 0.0652 - accuracy: 0.9762 - val_loss: 0.0572 - val_accuracy: 0.9822
# Epoch 29/50
# 2056/2056 [==============================] - 21s 10ms/step - loss: 0.0643 - accuracy: 0.9764 - val_loss: 0.0493 - val_accuracy: 0.9868
# Epoch 30/50
# 2056/2056 [==============================] - 21s 10ms/step - loss: 0.0643 - accuracy: 0.9764 - val_loss: 0.0446 - val_accuracy: 0.9885
# Fold 2 Accuracy: 0.9882
#
# ------ Fold 3 ------
# Epoch 1/50
# 2053/2053 [==============================] - 21s 10ms/step - loss: 0.2673 - accuracy: 0.9048 - val_loss: 0.1145 - val_accuracy: 0.9568
# Epoch 2/50
# 2053/2053 [==============================] - 21s 10ms/step - loss: 0.1388 - accuracy: 0.9512 - val_loss: 0.1158 - val_accuracy: 0.9637
# Epoch 3/50
# 2053/2053 [==============================] - 21s 10ms/step - loss: 0.1160 - accuracy: 0.9594 - val_loss: 0.0580 - val_accuracy: 0.9823
# Epoch 4/50
# 2053/2053 [==============================] - 21s 10ms/step - loss: 0.1045 - accuracy: 0.9635 - val_loss: 0.0970 - val_accuracy: 0.9709
# Epoch 5/50
# 2053/2053 [==============================] - 21s 10ms/step - loss: 0.0972 - accuracy: 0.9661 - val_loss: 0.0547 - val_accuracy: 0.9833
# Epoch 6/50
# 2053/2053 [==============================] - 21s 10ms/step - loss: 0.0940 - accuracy: 0.9671 - val_loss: 0.0740 - val_accuracy: 0.9787
# Epoch 7/50
# 2053/2053 [==============================] - 22s 11ms/step - loss: 0.0895 - accuracy: 0.9686 - val_loss: 0.0530 - val_accuracy: 0.9838
# Epoch 8/50
# 2053/2053 [==============================] - 21s 10ms/step - loss: 0.0863 - accuracy: 0.9697 - val_loss: 0.1281 - val_accuracy: 0.9602
# Epoch 9/50
# 2053/2053 [==============================] - 21s 10ms/step - loss: 0.0836 - accuracy: 0.9704 - val_loss: 0.0594 - val_accuracy: 0.9831
# Epoch 10/50
# 2053/2053 [==============================] - 22s 11ms/step - loss: 0.0817 - accuracy: 0.9709 - val_loss: 0.0737 - val_accuracy: 0.9796
# Epoch 11/50
# 2053/2053 [==============================] - 22s 11ms/step - loss: 0.0800 - accuracy: 0.9716 - val_loss: 0.0947 - val_accuracy: 0.9760
# Epoch 12/50
# 2053/2053 [==============================] - 21s 10ms/step - loss: 0.0781 - accuracy: 0.9720 - val_loss: 0.0523 - val_accuracy: 0.9849
# Epoch 13/50
# 2053/2053 [==============================] - 21s 10ms/step - loss: 0.0763 - accuracy: 0.9729 - val_loss: 0.0465 - val_accuracy: 0.9866
# Epoch 14/50
# 2053/2053 [==============================] - 21s 10ms/step - loss: 0.0748 - accuracy: 0.9731 - val_loss: 0.0921 - val_accuracy: 0.9742
# Epoch 15/50
# 2053/2053 [==============================] - 21s 10ms/step - loss: 0.0736 - accuracy: 0.9735 - val_loss: 0.0473 - val_accuracy: 0.9867
# Epoch 16/50
# 2053/2053 [==============================] - 21s 10ms/step - loss: 0.0722 - accuracy: 0.9742 - val_loss: 0.0498 - val_accuracy: 0.9847
# Epoch 17/50
# 2053/2053 [==============================] - 21s 10ms/step - loss: 0.0710 - accuracy: 0.9744 - val_loss: 0.0447 - val_accuracy: 0.9873
# Epoch 18/50
# 2053/2053 [==============================] - 21s 10ms/step - loss: 0.0698 - accuracy: 0.9749 - val_loss: 0.0555 - val_accuracy: 0.9835
# Epoch 19/50
# 2053/2053 [==============================] - 23s 11ms/step - loss: 0.0690 - accuracy: 0.9752 - val_loss: 0.0485 - val_accuracy: 0.9870
# Epoch 20/50
# 2053/2053 [==============================] - 23s 11ms/step - loss: 0.0687 - accuracy: 0.9753 - val_loss: 0.0763 - val_accuracy: 0.9814
# Epoch 21/50
# 2053/2053 [==============================] - 22s 11ms/step - loss: 0.0672 - accuracy: 0.9757 - val_loss: 0.0532 - val_accuracy: 0.9856
# Epoch 22/50
# 2053/2053 [==============================] - 24s 12ms/step - loss: 0.0672 - accuracy: 0.9759 - val_loss: 0.0456 - val_accuracy: 0.9873
# Epoch 23/50
# 2053/2053 [==============================] - 22s 11ms/step - loss: 0.0661 - accuracy: 0.9761 - val_loss: 0.0986 - val_accuracy: 0.9778
# Epoch 24/50
# 2053/2053 [==============================] - 22s 11ms/step - loss: 0.0651 - accuracy: 0.9766 - val_loss: 0.0483 - val_accuracy: 0.9874
# Epoch 25/50
# 2053/2053 [==============================] - 22s 11ms/step - loss: 0.0645 - accuracy: 0.9768 - val_loss: 0.0458 - val_accuracy: 0.9871
# Epoch 26/50
# 2053/2053 [==============================] - 22s 11ms/step - loss: 0.0636 - accuracy: 0.9772 - val_loss: 0.0602 - val_accuracy: 0.9819
# Epoch 27/50
# 2053/2053 [==============================] - 22s 11ms/step - loss: 0.0631 - accuracy: 0.9774 - val_loss: 0.0441 - val_accuracy: 0.9883
# Epoch 28/50
# 2053/2053 [==============================] - 22s 11ms/step - loss: 0.0632 - accuracy: 0.9775 - val_loss: 0.0529 - val_accuracy: 0.9864
# Epoch 29/50
# 2053/2053 [==============================] - 22s 11ms/step - loss: 0.0622 - accuracy: 0.9776 - val_loss: 0.0651 - val_accuracy: 0.9846
# Epoch 30/50
# 2053/2053 [==============================] - 22s 11ms/step - loss: 0.0611 - accuracy: 0.9780 - val_loss: 0.0441 - val_accuracy: 0.9882
# Epoch 31/50
# 2053/2053 [==============================] - 22s 11ms/step - loss: 0.0607 - accuracy: 0.9782 - val_loss: 0.0608 - val_accuracy: 0.9854
# Epoch 32/50
# 2053/2053 [==============================] - 24s 12ms/step - loss: 0.0605 - accuracy: 0.9784 - val_loss: 0.0457 - val_accuracy: 0.9877
# Epoch 33/50
# 2053/2053 [==============================] - 22s 11ms/step - loss: 0.0603 - accuracy: 0.9784 - val_loss: 0.0501 - val_accuracy: 0.9870
# Epoch 34/50
# 2053/2053 [==============================] - 22s 11ms/step - loss: 0.0600 - accuracy: 0.9786 - val_loss: 0.0585 - val_accuracy: 0.9840
# Epoch 35/50
# 2053/2053 [==============================] - 21s 10ms/step - loss: 0.0592 - accuracy: 0.9788 - val_loss: 0.1035 - val_accuracy: 0.9729
# Epoch 36/50
# 2053/2053 [==============================] - 21s 10ms/step - loss: 0.0588 - accuracy: 0.9790 - val_loss: 0.0697 - val_accuracy: 0.9828
# Epoch 37/50
# 2053/2053 [==============================] - 21s 10ms/step - loss: 0.0587 - accuracy: 0.9789 - val_loss: 0.0473 - val_accuracy: 0.9870
# Epoch 38/50
# 2053/2053 [==============================] - 22s 11ms/step - loss: 0.0587 - accuracy: 0.9789 - val_loss: 0.0468 - val_accuracy: 0.9866
# Epoch 39/50
# 2053/2053 [==============================] - 23s 11ms/step - loss: 0.0579 - accuracy: 0.9793 - val_loss: 0.0435 - val_accuracy: 0.9883
# Epoch 40/50
# 2053/2053 [==============================] - 24s 11ms/step - loss: 0.0575 - accuracy: 0.9795 - val_loss: 0.0461 - val_accuracy: 0.9883
# Epoch 41/50
# 2053/2053 [==============================] - 22s 11ms/step - loss: 0.0578 - accuracy: 0.9793 - val_loss: 0.0526 - val_accuracy: 0.9871
# Epoch 42/50
# 2053/2053 [==============================] - 21s 10ms/step - loss: 0.0568 - accuracy: 0.9796 - val_loss: 0.0511 - val_accuracy: 0.9875
# Epoch 43/50
# 2053/2053 [==============================] - 21s 10ms/step - loss: 0.0566 - accuracy: 0.9798 - val_loss: 0.0864 - val_accuracy: 0.9831
# Epoch 44/50
# 2053/2053 [==============================] - 21s 10ms/step - loss: 0.0562 - accuracy: 0.9799 - val_loss: 0.0630 - val_accuracy: 0.9850
# Epoch 45/50
# 2053/2053 [==============================] - 22s 11ms/step - loss: 0.0560 - accuracy: 0.9799 - val_loss: 0.0442 - val_accuracy: 0.9889
# Epoch 46/50
# 2053/2053 [==============================] - 23s 11ms/step - loss: 0.0559 - accuracy: 0.9800 - val_loss: 0.0419 - val_accuracy: 0.9899
# Epoch 47/50
# 2053/2053 [==============================] - 22s 11ms/step - loss: 0.0553 - accuracy: 0.9801 - val_loss: 0.0599 - val_accuracy: 0.9847
# Epoch 48/50
# 2053/2053 [==============================] - 22s 11ms/step - loss: 0.0554 - accuracy: 0.9801 - val_loss: 0.0437 - val_accuracy: 0.9890
# Epoch 49/50
# 2053/2053 [==============================] - 22s 11ms/step - loss: 0.0553 - accuracy: 0.9801 - val_loss: 0.0813 - val_accuracy: 0.9829
# Epoch 50/50
# 2053/2053 [==============================] - 23s 11ms/step - loss: 0.0547 - accuracy: 0.9804 - val_loss: 0.0441 - val_accuracy: 0.9893
# --> En iyi model fold 3 olarak kaydedildi!
# Fold 3 Accuracy: 0.9893
#
# ------ Fold 4 ------
# Epoch 1/50
# 2056/2056 [==============================] - 22s 10ms/step - loss: 0.2756 - accuracy: 0.9008 - val_loss: 0.1436 - val_accuracy: 0.9467
# Epoch 2/50
# 2056/2056 [==============================] - 22s 11ms/step - loss: 0.1570 - accuracy: 0.9437 - val_loss: 0.0946 - val_accuracy: 0.9690
# Epoch 3/50
# 2056/2056 [==============================] - 22s 11ms/step - loss: 0.1325 - accuracy: 0.9522 - val_loss: 0.0767 - val_accuracy: 0.9740
# Epoch 4/50
# 2056/2056 [==============================] - 22s 11ms/step - loss: 0.1193 - accuracy: 0.9567 - val_loss: 0.0712 - val_accuracy: 0.9738
# Epoch 5/50
# 2056/2056 [==============================] - 23s 11ms/step - loss: 0.1120 - accuracy: 0.9592 - val_loss: 0.0886 - val_accuracy: 0.9674
# Epoch 6/50
# 2056/2056 [==============================] - 22s 11ms/step - loss: 0.1051 - accuracy: 0.9615 - val_loss: 0.0856 - val_accuracy: 0.9681
# Epoch 7/50
# 2056/2056 [==============================] - 21s 10ms/step - loss: 0.1006 - accuracy: 0.9629 - val_loss: 0.0796 - val_accuracy: 0.9735
# Epoch 8/50
# 2056/2056 [==============================] - 21s 10ms/step - loss: 0.0966 - accuracy: 0.9644 - val_loss: 0.0603 - val_accuracy: 0.9821
# Epoch 9/50
# 2056/2056 [==============================] - 22s 11ms/step - loss: 0.0931 - accuracy: 0.9660 - val_loss: 0.0587 - val_accuracy: 0.9815
# Epoch 10/50
# 2056/2056 [==============================] - 22s 11ms/step - loss: 0.0883 - accuracy: 0.9684 - val_loss: 0.0487 - val_accuracy: 0.9854
# Epoch 11/50
# 2056/2056 [==============================] - 23s 11ms/step - loss: 0.0842 - accuracy: 0.9698 - val_loss: 0.0534 - val_accuracy: 0.9834
# Epoch 12/50
# 2056/2056 [==============================] - 23s 11ms/step - loss: 0.0816 - accuracy: 0.9707 - val_loss: 0.1013 - val_accuracy: 0.9683
# Epoch 13/50
# 2056/2056 [==============================] - 23s 11ms/step - loss: 0.0798 - accuracy: 0.9713 - val_loss: 0.0478 - val_accuracy: 0.9860
# Epoch 14/50
# 2056/2056 [==============================] - 23s 11ms/step - loss: 0.0775 - accuracy: 0.9721 - val_loss: 0.0459 - val_accuracy: 0.9867
# Epoch 15/50
# 2056/2056 [==============================] - 23s 11ms/step - loss: 0.0767 - accuracy: 0.9723 - val_loss: 0.0654 - val_accuracy: 0.9815
# Epoch 16/50
# 2056/2056 [==============================] - 23s 11ms/step - loss: 0.0753 - accuracy: 0.9728 - val_loss: 0.0482 - val_accuracy: 0.9858
# Epoch 17/50
# 2056/2056 [==============================] - 23s 11ms/step - loss: 0.0741 - accuracy: 0.9732 - val_loss: 0.0484 - val_accuracy: 0.9864
# Epoch 18/50
# 2056/2056 [==============================] - 23s 11ms/step - loss: 0.0731 - accuracy: 0.9735 - val_loss: 0.0668 - val_accuracy: 0.9796
# Epoch 19/50
# 2056/2056 [==============================] - 23s 11ms/step - loss: 0.0720 - accuracy: 0.9740 - val_loss: 0.0808 - val_accuracy: 0.9738
# Epoch 20/50
# 2056/2056 [==============================] - 23s 11ms/step - loss: 0.0704 - accuracy: 0.9744 - val_loss: 0.0449 - val_accuracy: 0.9875
# Epoch 21/50
# 2056/2056 [==============================] - 22s 11ms/step - loss: 0.0696 - accuracy: 0.9747 - val_loss: 0.0503 - val_accuracy: 0.9852
# Epoch 22/50
# 2056/2056 [==============================] - 21s 10ms/step - loss: 0.0690 - accuracy: 0.9748 - val_loss: 0.0484 - val_accuracy: 0.9869
# Epoch 23/50
# 2056/2056 [==============================] - 21s 10ms/step - loss: 0.0679 - accuracy: 0.9753 - val_loss: 0.0535 - val_accuracy: 0.9863
# Epoch 24/50
# 2056/2056 [==============================] - 21s 10ms/step - loss: 0.0675 - accuracy: 0.9754 - val_loss: 0.0485 - val_accuracy: 0.9859
# Epoch 25/50
# 2056/2056 [==============================] - 21s 10ms/step - loss: 0.0664 - accuracy: 0.9758 - val_loss: 0.0494 - val_accuracy: 0.9856
# Epoch 26/50
# 2056/2056 [==============================] - 22s 10ms/step - loss: 0.0658 - accuracy: 0.9760 - val_loss: 0.0623 - val_accuracy: 0.9832
# Epoch 27/50
# 2056/2056 [==============================] - 21s 10ms/step - loss: 0.0652 - accuracy: 0.9763 - val_loss: 0.0673 - val_accuracy: 0.9784
# Epoch 28/50
# 2056/2056 [==============================] - 21s 10ms/step - loss: 0.0642 - accuracy: 0.9765 - val_loss: 0.0463 - val_accuracy: 0.9863
# Epoch 29/50
# 2056/2056 [==============================] - 24s 12ms/step - loss: 0.0643 - accuracy: 0.9764 - val_loss: 0.0406 - val_accuracy: 0.9892
# Epoch 30/50
# 2056/2056 [==============================] - 21s 10ms/step - loss: 0.0634 - accuracy: 0.9767 - val_loss: 0.0513 - val_accuracy: 0.9854
# Epoch 31/50
# 2056/2056 [==============================] - 21s 10ms/step - loss: 0.0628 - accuracy: 0.9769 - val_loss: 0.0451 - val_accuracy: 0.9880
# Epoch 32/50
# 2056/2056 [==============================] - 21s 10ms/step - loss: 0.0623 - accuracy: 0.9771 - val_loss: 0.0509 - val_accuracy: 0.9859
# Epoch 33/50
# 2056/2056 [==============================] - 21s 10ms/step - loss: 0.0621 - accuracy: 0.9771 - val_loss: 0.0447 - val_accuracy: 0.9878
# Epoch 34/50
# 2056/2056 [==============================] - 21s 10ms/step - loss: 0.0619 - accuracy: 0.9774 - val_loss: 0.0575 - val_accuracy: 0.9855
# Epoch 35/50
# 2056/2056 [==============================] - 22s 10ms/step - loss: 0.0616 - accuracy: 0.9774 - val_loss: 0.0429 - val_accuracy: 0.9886
# Epoch 36/50
# 2056/2056 [==============================] - 21s 10ms/step - loss: 0.0610 - accuracy: 0.9775 - val_loss: 0.0523 - val_accuracy: 0.9852
# Epoch 37/50
# 2056/2056 [==============================] - 21s 10ms/step - loss: 0.0603 - accuracy: 0.9780 - val_loss: 0.0450 - val_accuracy: 0.9887
# Epoch 38/50
# 2056/2056 [==============================] - 21s 10ms/step - loss: 0.0601 - accuracy: 0.9778 - val_loss: 0.0455 - val_accuracy: 0.9876
# Epoch 39/50
# 2056/2056 [==============================] - 21s 10ms/step - loss: 0.0598 - accuracy: 0.9780 - val_loss: 0.0457 - val_accuracy: 0.9890
# Fold 4 Accuracy: 0.9892
#
# ------ Fold 5 ------
# Epoch 1/50
# 2053/2053 [==============================] - 22s 10ms/step - loss: 0.2824 - accuracy: 0.8978 - val_loss: 0.1158 - val_accuracy: 0.9580
# Epoch 2/50
# 2053/2053 [==============================] - 21s 10ms/step - loss: 0.1640 - accuracy: 0.9416 - val_loss: 0.1256 - val_accuracy: 0.9558
# Epoch 3/50
# 2053/2053 [==============================] - 21s 10ms/step - loss: 0.1401 - accuracy: 0.9494 - val_loss: 0.0703 - val_accuracy: 0.9791
# Epoch 4/50
# 2053/2053 [==============================] - 21s 10ms/step - loss: 0.1252 - accuracy: 0.9548 - val_loss: 0.1009 - val_accuracy: 0.9626
# Epoch 5/50
# 2053/2053 [==============================] - 21s 10ms/step - loss: 0.1160 - accuracy: 0.9578 - val_loss: 0.0712 - val_accuracy: 0.9762
# Epoch 6/50
# 2053/2053 [==============================] - 21s 10ms/step - loss: 0.1099 - accuracy: 0.9598 - val_loss: 0.0821 - val_accuracy: 0.9709
# Epoch 7/50
# 2053/2053 [==============================] - 21s 10ms/step - loss: 0.1056 - accuracy: 0.9612 - val_loss: 0.0664 - val_accuracy: 0.9773
# Epoch 8/50
# 2053/2053 [==============================] - 21s 10ms/step - loss: 0.1018 - accuracy: 0.9624 - val_loss: 0.0856 - val_accuracy: 0.9681
# Epoch 9/50
# 2053/2053 [==============================] - 21s 10ms/step - loss: 0.0989 - accuracy: 0.9635 - val_loss: 0.0640 - val_accuracy: 0.9789
# Epoch 10/50
# 2053/2053 [==============================] - 22s 10ms/step - loss: 0.0961 - accuracy: 0.9643 - val_loss: 0.0572 - val_accuracy: 0.9813
# Epoch 11/50
# 2053/2053 [==============================] - 21s 10ms/step - loss: 0.0936 - accuracy: 0.9652 - val_loss: 0.0616 - val_accuracy: 0.9818
# Epoch 12/50
# 2053/2053 [==============================] - 21s 10ms/step - loss: 0.0923 - accuracy: 0.9658 - val_loss: 0.0637 - val_accuracy: 0.9775
# Epoch 13/50
# 2053/2053 [==============================] - 21s 10ms/step - loss: 0.0897 - accuracy: 0.9666 - val_loss: 0.0573 - val_accuracy: 0.9797
# Epoch 14/50
# 2053/2053 [==============================] - 21s 10ms/step - loss: 0.0887 - accuracy: 0.9668 - val_loss: 0.0598 - val_accuracy: 0.9789
# Epoch 15/50
# 2053/2053 [==============================] - 21s 10ms/step - loss: 0.0868 - accuracy: 0.9676 - val_loss: 0.0738 - val_accuracy: 0.9743
# Epoch 16/50
# 2053/2053 [==============================] - 21s 10ms/step - loss: 0.0862 - accuracy: 0.9676 - val_loss: 0.0629 - val_accuracy: 0.9753
# Epoch 17/50
# 2053/2053 [==============================] - 21s 10ms/step - loss: 0.0852 - accuracy: 0.9680 - val_loss: 0.0713 - val_accuracy: 0.9745
# Epoch 18/50
# 2053/2053 [==============================] - 21s 10ms/step - loss: 0.0832 - accuracy: 0.9688 - val_loss: 0.0575 - val_accuracy: 0.9808
# Epoch 19/50
# 2053/2053 [==============================] - 21s 10ms/step - loss: 0.0817 - accuracy: 0.9692 - val_loss: 0.0457 - val_accuracy: 0.9873
# Epoch 20/50
# 2053/2053 [==============================] - 21s 10ms/step - loss: 0.0815 - accuracy: 0.9697 - val_loss: 0.0512 - val_accuracy: 0.9850
# Epoch 21/50
# 2053/2053 [==============================] - 21s 10ms/step - loss: 0.0812 - accuracy: 0.9694 - val_loss: 0.0582 - val_accuracy: 0.9847
# Epoch 22/50
# 2053/2053 [==============================] - 21s 10ms/step - loss: 0.0799 - accuracy: 0.9700 - val_loss: 0.0568 - val_accuracy: 0.9804
# Epoch 23/50
# 2053/2053 [==============================] - 23s 11ms/step - loss: 0.0785 - accuracy: 0.9706 - val_loss: 0.0540 - val_accuracy: 0.9851
# Epoch 24/50
# 2053/2053 [==============================] - 20s 10ms/step - loss: 0.0781 - accuracy: 0.9706 - val_loss: 0.0491 - val_accuracy: 0.9859
# Epoch 25/50
# 2053/2053 [==============================] - 20s 10ms/step - loss: 0.0774 - accuracy: 0.9708 - val_loss: 0.0539 - val_accuracy: 0.9830
# Epoch 26/50
# 2053/2053 [==============================] - 22s 11ms/step - loss: 0.0767 - accuracy: 0.9712 - val_loss: 0.1240 - val_accuracy: 0.9665
# Epoch 27/50
# 2053/2053 [==============================] - 22s 11ms/step - loss: 0.0756 - accuracy: 0.9714 - val_loss: 0.0526 - val_accuracy: 0.9833
# Epoch 28/50
# 2053/2053 [==============================] - 22s 11ms/step - loss: 0.0757 - accuracy: 0.9716 - val_loss: 0.0515 - val_accuracy: 0.9838
# Epoch 29/50
# 2053/2053 [==============================] - 22s 11ms/step - loss: 0.0747 - accuracy: 0.9718 - val_loss: 0.0586 - val_accuracy: 0.9793
# Fold 5 Accuracy: 0.9873
#
# K-Fold Ortalama Accuracy: 0.9886229038238525
# En iyi fold accuracy: 0.989322304725647

# %%
from sklearn.metrics import f1_score

final_imputer = imputer

X_test_imputed = final_imputer.transform(X_test)
y_pred_probs = model.predict(X_test_imputed)
y_pred = np.argmax(y_pred_probs, axis=1)

test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
test_f1 = f1_score(y_test, y_pred, average="weighted")

print("\nTest Accuracy:", test_acc)
print("Test F1 Score:", test_f1)
# Out:
# 3921/3921 [==============================] - 7s 2ms/step
#
# Test Accuracy: 0.987877607345581
# Test F1 Score: 0.9878686102971956

# %%
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_auc_score

y_test_bin = label_binarize(y_test, classes=[0,1,2,3])

test_auc = roc_auc_score(
    y_test_bin,
    y_pred_probs,
    average="weighted",
    multi_class="ovr"
)

print("Test AUC:", test_auc)
# Out:
# Test AUC: 0.999436350332857

# %%
from sklearn.metrics import confusion_matrix, classification_report

class_names = ['Benign (0)', 'Defacement (1)', 'Phishing (2)', 'Malware (3)']

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Reds', 
            xticklabels=class_names, 
            yticklabels=class_names)
plt.title('Confusion Matrix (Model Tahmin Analizi)')
plt.ylabel('Gerçek Sınıf')
plt.xlabel('Tahmin Edilen Sınıf')
plt.show()


print("\n--- Sınıflandırma Raporu ---")
print(classification_report(y_test, y_pred, target_names=class_names))
# Out:
# --- Sınıflandırma Raporu ---
#                 precision    recall  f1-score   support
#
#     Benign (0)       1.00      1.00      1.00     84093
# Defacement (1)       0.97      0.98      0.98     19288
#   Phishing (2)       0.97      0.97      0.97     16329
#    Malware (3)       0.95      0.94      0.94      5760
#
#       accuracy                           0.99    125470
#      macro avg       0.97      0.97      0.97    125470
#   weighted avg       0.99      0.99      0.99    125470

# %%
plt.figure(figsize=(8, 5))
plt.plot(history.history["accuracy"], label="Train Accuracy")
plt.plot(history.history["val_accuracy"], label="Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Train and Validation Accuracy over Epochs")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Train and Validation Loss over Epochs")
plt.legend()
plt.grid(True)
plt.show()
